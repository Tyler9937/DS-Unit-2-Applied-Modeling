# %% [markdown]
# <a href="https://colab.research.google.com/github/Tyler9937/DS-Unit-2-Applied-Modeling/blob/master/(U2W3A1_4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing pandas
#importing os as to work with local files
import pandas as pd
import os

#defining empty list
frames = []

#loading in all datasets
#datasets are named in such a way to be loaded in like this
#this current path as 619 seperate csv files to be read in
for i in range(1,2):
    df = pd.read_csv(r"C:\Users\tyler\Desktop\all_data\z (" + str(i) + ").csv" )
    frames.append(df)

# %%
#merging all of the datasets together
#merged datasets depend on ones read into frames
df = pd.concat(frames, sort=True)

# %%
# testing for duplicate rows in the dataframe
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF = df[df.duplicated(subset=None, keep='first')]

#prints out duplacted rows if any
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [backers_count, blurb, category, converted_pledged_amount, country, created_at, creator, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, friends, fx_rate, goal, id, is_backing, is_starrable, is_starred, launched_at, location, name, permissions, photo, pledged, profile, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, unread_messages_count, unseen_activity_count, urls, usd_pledged, usd_type]
# Index: []

# %%
#checking df shape
df.shape
# Out:
# (3777, 39)

# %%
df.dtypes
# Out:
# backers_count                 int64
# blurb                        object
# category                     object
# converted_pledged_amount      int64
# country                      object
# created_at                    int64
# creator                      object
# currency                     object
# currency_symbol              object
# currency_trailing_code         bool
# current_currency             object
# deadline                      int64
# disable_communication          bool
# friends                      object
# fx_rate                     float64
# goal                          int64
# id                            int64
# is_backing                   object
# is_starrable                   bool
# is_starred                   object
# launched_at                   int64
# location                     object
# name                         object
# permissions                  object
# photo                        object
# pledged                     float64
# profile                      object
# slug                         object
# source_url                   object
# spotlight                      bool
# staff_pick                     bool
# state                        object
# state_changed_at              int64
# static_usd_rate             float64
# unread_messages_count       float64
# unseen_activity_count       float64
# urls                         object
# usd_pledged                 float64
# usd_type                     object
# dtype: object

# %%
#looking at df
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    backers_count                                              blurb  \
# 0             38  Patented, beautifully designed crank flashligh...
# 1            744  Let's make three more episodes of Crash Zoom! ...
# 2            260  Can a wall plug be smart, dynamic, and compact...
# 3             15  A Science, Math, History and Reading Adventure...
# 4             58  A High-Fantasy short film that proves you don'...
#
#                                             category  \
# 0  {"id":337,"name":"Gadgets","slug":"technology/...
# 1  {"id":29,"name":"Animation","slug":"film & vid...
# 2  {"id":337,"name":"Gadgets","slug":"technology/...
# 3  {"id":272,"name":"Mobile Games","slug":"games/...
# 4  {"id":296,"name":"Fantasy","slug":"film & vide...
#
#    converted_pledged_amount country  created_at  \
# 0                      5166      US  1422132218
# 1                     42669      GB  1526567487
# 2                     50673      US  1492618297
# 3                       477      US  1340296119
# 4                      9386      US  1531443999
#
#                                              creator currency currency_symbol  \
# 0  {"id":1435541211,"name":"Bill Evans & Stan Tan...      USD               $
# 1  {"id":1897952907,"name":"Thomas 'TomSka' Ridge...      GBP               £
# 2  {"id":1307908807,"name":"Svetlana Schubert and...      USD               $
# 3  {"id":1767325640,"name":"Chump Genius, Inc.","...      USD               $
# 4  {"id":1518998549,"name":"Matthew R. R. Morrese...      USD               $
#
#    currency_trailing_code current_currency    deadline  disable_communication  \
# 0                    True              USD  1428601725                  False
# 1                   False              USD  1529514000                  False
# 2                    True              USD  1507999196                  False
# 3                    True              USD  1365094464                  False
# 4                    True              USD  1535266740                  False
#
#   friends  fx_rate   goal          id is_backing  is_starrable is_starred  \
# 0     NaN   1.0000   5000  1221407538        NaN         False        NaN
# 1     NaN   1.2688  25000  1834819986        NaN         False        NaN
# 2     NaN   1.0000  50000   833051480        NaN         False        NaN
# 3     NaN   1.0000  50000  2132116123        NaN         False        NaN
# 4     NaN   1.0000   5000  1600103518        NaN         False        NaN
#
#    launched_at                                           location  \
# 0   1426009725  {"id":2463583,"name":"Oakland","slug":"oakland...
# 1   1526666567  {"id":44418,"name":"London","slug":"london-gb"...
# 2   1502815196  {"id":2391446,"name":"Des Moines","slug":"des-...
# 3   1362506064  {"id":2379574,"name":"Chicago","slug":"chicago...
# 4   1533509428  {"id":2486982,"name":"St. Louis","slug":"st-lo...
#
#                                                 name permissions  \
# 0  Hardware Art:  Small Batch Crank Flashlight & ...         NaN
# 1           Crash Zoom - Series 2 (Animated Webtoon)         NaN
# 2  SnuggPlug 3.0 - Smart&Slim Multi USB Wall Charger         NaN
# 3                         Chump Genius Card Game App         NaN
# 4           Canticles: The Adventure Brought to Life         NaN
#
#                                                photo   pledged  \
# 0  {"key":"assets/012/012/636/94bd8000567dfc797dc...   5166.00
# 1  {"key":"assets/021/264/487/8b499c0916817eafc84...  32421.97
# 2  {"key":"assets/016/481/036/b782c69e382d86eed73...  50673.00
# 3  {"key":"assets/011/384/429/b38377340b1fcbc0508...    477.00
# 4  {"key":"assets/021/885/313/e29be0fb443a996dc31...   9386.00
#
#                                              profile  \
# 0  {"id":1656118,"project_id":1656118,"state":"in...
# 1  {"id":3383801,"project_id":3383801,"state":"in...
# 2  {"id":2967810,"project_id":2967810,"state":"in...
# 3  {"id":234651,"project_id":234651,"state":"inac...
# 4  {"id":3424107,"project_id":3424107,"state":"in...
#
#                                                 slug  \
# 0  hardware-art-small-batch-crank-flashlight-and-...
# 1               crash-zoom-series-2-animated-webtoon
# 2  the-snuggplug-smart-and-slim-space-saving-usb-...
# 3                         chump-genius-card-game-app
# 4            canticles-the-adventure-brought-to-life
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...       True        True
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...      False       False
# 4  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  unread_messages_count  \
# 0  successful        1428601726         1.000000                    NaN
# 1  successful        1529514000         1.355851                    NaN
# 2  successful        1507999196         1.000000                    NaN
# 3      failed        1365094466         1.000000                    NaN
# 4  successful        1535266742         1.000000                    NaN
#
#    unseen_activity_count                                               urls  \
# 0                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 1                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 2                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 3                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 4                    NaN  {"web":{"project":"https://www.kickstarter.com...
#
#     usd_pledged  usd_type
# 0   5166.000000  domestic
# 1  43959.370497  domestic
# 2  50673.000000  domestic
# 3    477.000000  domestic
# 4   9386.000000  domestic

# %%
#print(df['urls'][0])
print(df['profile'][0])
print(df['location'][2])
#print(df['creator'][0])
# Out:
# {"id":1656118,"project_id":1656118,"state":"inactive","state_changed_at":1425915891,"name":null,"blurb":null,"background_color":null,"text_color":null,"link_background_color":null,"link_text_color":null,"link_text":null,"link_url":null,"show_feature_image":false,"background_image_opacity":0.8,"should_show_feature_image_section":true,"feature_image_attributes":{"image_urls":{"default":"https://ksr-ugc.imgix.net/assets/012/012/636/94bd8000567dfc797dc3ea543bd8a8f6_original.jpg?ixlib=rb-2.0.0&crop=faces&w=1552&h=873&fit=crop&v=1463723997&auto=format&frame=1&q=92&s=4bd8ee4f8e1c08e3c163d0590ec9470c","baseball_card":"https://ksr-ugc.imgix.net/assets/012/012/636/94bd8000567dfc797dc3ea543bd8a8f6_original.jpg?ixlib=rb-2.0.0&crop=faces&w=560&h=315&fit=crop&v=1463723997&auto=format&frame=1&q=92&s=d753644d71d03b6202ba0a891c752ab9"}}}
# {"id":2391446,"name":"Des Moines","slug":"des-moines-ia","short_name":"Des Moines, IA","displayable_name":"Des Moines, IA","localized_name":"Des Moines","country":"US","state":"IA","type":"Town","is_root":false,"urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/des-moines-ia","location":"https://www.kickstarter.com/locations/des-moines-ia"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1560466574.1ea8569b14a716ea742c9f932b49269445a02547&woe_id=2391446"}}}

# %%
df.isnull().sum()
# Out:
# backers_count                  0
# blurb                          0
# category                       0
# converted_pledged_amount       0
# country                        0
# created_at                     0
# creator                        0
# currency                       0
# currency_symbol                0
# currency_trailing_code         0
# current_currency               0
# deadline                       0
# disable_communication          0
# friends                     3773
# fx_rate                        0
# goal                           0
# id                             0
# is_backing                  3773
# is_starrable                   0
# is_starred                  3773
# launched_at                    0
# location                       2
# name                           0
# permissions                 3773
# photo                          0
# pledged                        0
# profile                        0
# slug                           0
# source_url                     0
# spotlight                      0
# staff_pick                     0
# state                          0
# state_changed_at               0
# static_usd_rate                0
# unread_messages_count       3777
# unseen_activity_count       3777
# urls                           0
# usd_pledged                    0
# usd_type                       3
# dtype: int64

# %%
df.dropna(subset=['location'], inplace=True)

# %%
#creating a function that converts strings to dictionaries
import json 

def cat_to_dic(x):
   return json.loads(x) 

import ast
def loc_to_dic(x):
    return ast.literal_eval(str(x))



df['category_dic'] = df['category'].apply(cat_to_dic)
df['location_dic'] = df['location'].apply(cat_to_dic)

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0             38  Patented, beautifully designed crank flashligh...
# 1            744  Let's make three more episodes of Crash Zoom! ...
# 2            260  Can a wall plug be smart, dynamic, and compact...
# 3             15  A Science, Math, History and Reading Adventure...
# 4             58  A High-Fantasy short film that proves you don'...
#
#                                             category  \
# 0  {"id":337,"name":"Gadgets","slug":"technology/...
# 1  {"id":29,"name":"Animation","slug":"film & vid...
# 2  {"id":337,"name":"Gadgets","slug":"technology/...
# 3  {"id":272,"name":"Mobile Games","slug":"games/...
# 4  {"id":296,"name":"Fantasy","slug":"film & vide...
#
#    converted_pledged_amount country  created_at  \
# 0                      5166      US  1422132218
# 1                     42669      GB  1526567487
# 2                     50673      US  1492618297
# 3                       477      US  1340296119
# 4                      9386      US  1531443999
#
#                                              creator currency currency_symbol  \
# 0  {"id":1435541211,"name":"Bill Evans & Stan Tan...      USD               $
# 1  {"id":1897952907,"name":"Thomas 'TomSka' Ridge...      GBP               £
# 2  {"id":1307908807,"name":"Svetlana Schubert and...      USD               $
# 3  {"id":1767325640,"name":"Chump Genius, Inc.","...      USD               $
# 4  {"id":1518998549,"name":"Matthew R. R. Morrese...      USD               $
#
#    currency_trailing_code current_currency    deadline  disable_communication  \
# 0                    True              USD  1428601725                  False
# 1                   False              USD  1529514000                  False
# 2                    True              USD  1507999196                  False
# 3                    True              USD  1365094464                  False
# 4                    True              USD  1535266740                  False
#
#   friends  fx_rate   goal          id is_backing  is_starrable is_starred  \
# 0     NaN   1.0000   5000  1221407538        NaN         False        NaN
# 1     NaN   1.2688  25000  1834819986        NaN         False        NaN
# 2     NaN   1.0000  50000   833051480        NaN         False        NaN
# 3     NaN   1.0000  50000  2132116123        NaN         False        NaN
# 4     NaN   1.0000   5000  1600103518        NaN         False        NaN
#
#    launched_at                                           location  \
# 0   1426009725  {"id":2463583,"name":"Oakland","slug":"oakland...
# 1   1526666567  {"id":44418,"name":"London","slug":"london-gb"...
# 2   1502815196  {"id":2391446,"name":"Des Moines","slug":"des-...
# 3   1362506064  {"id":2379574,"name":"Chicago","slug":"chicago...
# 4   1533509428  {"id":2486982,"name":"St. Louis","slug":"st-lo...
#
#                                                 name permissions  \
# 0  Hardware Art:  Small Batch Crank Flashlight & ...         NaN
# 1           Crash Zoom - Series 2 (Animated Webtoon)         NaN
# 2  SnuggPlug 3.0 - Smart&Slim Multi USB Wall Charger         NaN
# 3                         Chump Genius Card Game App         NaN
# 4           Canticles: The Adventure Brought to Life         NaN
#
#                                                photo   pledged  \
# 0  {"key":"assets/012/012/636/94bd8000567dfc797dc...   5166.00
# 1  {"key":"assets/021/264/487/8b499c0916817eafc84...  32421.97
# 2  {"key":"assets/016/481/036/b782c69e382d86eed73...  50673.00
# 3  {"key":"assets/011/384/429/b38377340b1fcbc0508...    477.00
# 4  {"key":"assets/021/885/313/e29be0fb443a996dc31...   9386.00
#
#                                              profile  \
# 0  {"id":1656118,"project_id":1656118,"state":"in...
# 1  {"id":3383801,"project_id":3383801,"state":"in...
# 2  {"id":2967810,"project_id":2967810,"state":"in...
# 3  {"id":234651,"project_id":234651,"state":"inac...
# 4  {"id":3424107,"project_id":3424107,"state":"in...
#
#                                                 slug  \
# 0  hardware-art-small-batch-crank-flashlight-and-...
# 1               crash-zoom-series-2-animated-webtoon
# 2  the-snuggplug-smart-and-slim-space-saving-usb-...
# 3                         chump-genius-card-game-app
# 4            canticles-the-adventure-brought-to-life
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...       True        True
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...      False       False
# 4  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  unread_messages_count  \
# 0  successful        1428601726         1.000000                    NaN
# 1  successful        1529514000         1.355851                    NaN
# 2  successful        1507999196         1.000000                    NaN
# 3      failed        1365094466         1.000000                    NaN
# 4  successful        1535266742         1.000000                    NaN
#
#    unseen_activity_count                                               urls  \
# 0                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 1                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 2                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 3                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 4                    NaN  {"web":{"project":"https://www.kickstarter.com...
#
#     usd_pledged  usd_type                                       category_dic  \
# 0   5166.000000  domestic  {'id': 337, 'name': 'Gadgets', 'slug': 'techno...
# 1  43959.370497  domestic  {'id': 29, 'name': 'Animation', 'slug': 'film ...
# 2  50673.000000  domestic  {'id': 337, 'name': 'Gadgets', 'slug': 'techno...
# 3    477.000000  domestic  {'id': 272, 'name': 'Mobile Games', 'slug': 'g...
# 4   9386.000000  domestic  {'id': 296, 'name': 'Fantasy', 'slug': 'film &...
#
#                                         location_dic
# 0  {'id': 2463583, 'name': 'Oakland', 'slug': 'oa...
# 1  {'id': 44418, 'name': 'London', 'slug': 'londo...
# 2  {'id': 2391446, 'name': 'Des Moines', 'slug': ...
# 3  {'id': 2379574, 'name': 'Chicago', 'slug': 'ch...
# 4  {'id': 2486982, 'name': 'St. Louis', 'slug': '...

# %%
def cat_to_id(x):
    return x['id']
def cat_to_name(x):
    return x['name']
def cat_to_slug(x):
    return x['slug']
def cat_to_short_names(x):
    return x['short_names']
def cat_to_displayable_name(x):
    return x['displayable_name']
def cat_to_localized_name(x):
    return x['localized_name']

# %%
def cat_to_id(x):
    return x['id']
def cat_to_name(x):
    return x['name']
def cat_to_slug(x):
    return x['slug']
def cat_to_position(x):
    return x['position']
def cat_to_parent_id(x):
    return x['parent_id']
def cat_to_state(x):
    return x['state']
def cat_to_type(x):
    return x['type']
def cat_to_color(x):
    return x['color']

# %%
#Engineering new features
df['blurb_len'] = len(df['blurb'])
df['category_id'] = df['category_dic'].apply(cat_to_id)
df['category_name'] = df['category_dic'].apply(cat_to_name)
df['category_slug'] = df['category_dic'].apply(cat_to_slug)
df['category_position'] = df['category_dic'].apply(cat_to_position)
#df['category_parent_id'] = df['category_dic'].apply(cat_to_parent_id)
df['category_color'] = df['category_dic'].apply(cat_to_color)
df['is_usa'] = df['country'].str.contains('US')
df['is_usd'] = df['currency'].str.contains('USD')
df['name_length'] = len(df['name'])
df['slug_length'] = len(df['slug'])


df['location_id'] = df['location_dic'].apply(cat_to_id)
df['location_name'] = df['location_dic'].apply(cat_to_name)
#df['location_slug'] = df['location_dic'].apply(cat_to_slug)
#df['location_short_names'] = df['location_dic'].apply(cat_to_short_names)
#df['location_displayable_name'] = df['location_dic'].apply(cat_to_displayable_name)
df['location_state'] = df['location_dic'].apply(cat_to_state)

# %%
df['location_state'].fillna('test', inplace=True)

# %%
df['location_state'].isnull().sum()
# Out:
# 0

# %%
#roughly seperating df into train, val, and test
#train = df[0:2000]
#val = df[2000:3000]
#test = df[3000:778]

# %%
from sklearn.model_selection import train_test_split

# Split train into train & test
train, test = train_test_split(df, train_size=0.80, test_size=0.20, 
                              stratify=df['state'], random_state=42)

# Split train into train & val
train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              stratify=train['state'], random_state=42)

# %%
#bulk imorting libraries to be used in pipeline
import category_encoders as ce
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

#setting target as state
target = 'state'

#setting features as rest of columns minus columns that leak information 
#about the target
features = df.columns.drop([target, 'backers_count', 'converted_pledged_amount', 'fx_rate',
                           'is_backing', 'is_starrable', 'is_starred', 'permissions', 'pledged', 'profile',
                            'source_url', 'spotlight', 'state_changed_at', 'static_usd_rate',
                            'urls', 'usd_pledged', 'friends', 'usd_type', 'unseen_activity_count',
                            'category_dic', 'creator', 'currency_trailing_code', 'current_currency',
                           'disable_communication', 'location_dic', 'unread_messages_count',])

#removed temporayily
#'unread_messages_count', 'unseen_activity_count',

#creating our vars to be used in pipline
x_train = train[features]
y_train = train[target]
x_val = val[features]
y_val = val[target]
x_test = test[features]

# %%
df['state'].isnull().sum()
# Out:
# 0

# %%
#checking subset trains shape (features)
x_train.shape
# Out:
# (2416, 28)

# %%
#checking subset trains shape (target)
x_val.shape
# Out:
# (604, 28)

# %%
#finding the a baseline score for data

# there are five classes
# the code below shows the percentage
# of value_counts for each class

#using value_counts to find baseline
y_train.value_counts(normalize=True)
# Out:
# successful    0.525248
# failed        0.395695
# canceled      0.043460
# live          0.031871
# suspended     0.003725
# Name: state, dtype: float64

# %%
#creating the pipline using Random forest classifer
#using ordinal encoder to make objtypes numeric
#using simple imputer to fill in nans
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, n_jobs=1, random_state=0)
)

# Fit on train, score on val
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['blurb', 'category', 'country',
#                                       'currency', 'currency_symbol', 'location',
#                                       'name', 'photo', 'slug', 'category_name',
#                                       'category_slug', 'location_name',
#                                       'location_state'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value',
#                                 mapping=[{'col': 'blurb',
#                                           'data_type': dtype('O'),
#                                           'mapping': To...
#                 ('randomforestclassifier',
#                  RandomForestClassifier(bootstrap=True, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features='auto',
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=1,
#                                         oob_score=False, random_state=0,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
#printing out the validation accuracy
print('Train Accuracy', pipeline.score(x_train, y_train))
print('Validation Accuracy', pipeline.score(x_val, y_val))
# Out:
# Train Accuracy 1.0
# Validation Accuracy 0.7384105960264901

# %%
#getting test accuracy
y_pred = pipeline.predict(x_test)
y_test = test[target]
print('Test Accuracy', pipeline.score(x_test, y_test))
# Out:
# Test Accuracy 0.7072847682119205

# %%
#just analysising the data before plotting top features
print('X_train shape before encoding', x_train.shape)

encoder = pipeline.named_steps['ordinalencoder']
encoded = encoder.transform(x_train)

print('X_train shape after encoding', encoded.shape)
# Out:
# X_train shape before encoding (2416, 28)
# X_train shape after encoding (2416, 28)

# %%
encoded.columns
# Out:
# Index(['blurb', 'category', 'country', 'created_at', 'currency',
#        'currency_symbol', 'deadline', 'goal', 'id', 'launched_at', 'location',
#        'name', 'photo', 'slug', 'staff_pick', 'blurb_len', 'category_id',
#        'category_name', 'category_slug', 'category_position', 'category_color',
#        'is_usa', 'is_usd', 'name_length', 'slug_length', 'location_id',
#        'location_name', 'location_state'],
#       dtype='object')

# %%
encoded.columns[0]
# Out:
# 'blurb'

# %%
#using matplotlib to plot best features
#Important top features are based of original model
#not the hyperparameter tuned model
# %matplotlib inline
import matplotlib.pyplot as plt

# Get feature importances
rf = pipeline.named_steps['randomforestclassifier']
importances = pd.Series(rf.feature_importances_, encoded.columns[0:36])

# Plot top n feature importances
n = 20
plt.figure(figsize=(10,n/2))
plt.title(f'Top {n} features')
importances.sort_values()[-n:].plot.barh(color='grey');

# %%
#testing feature selection method from lecture

# %%
transformers = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

# %%
#testing out that feature selection tool learned today
x_train_transformed = transformers.fit_transform(x_train)
x_val_transformed = transformers.transform(x_val)

model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(x_train_transformed, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
import eli5
from eli5.sklearn import PermutationImportance

# 1. Calculate permutation importances
permuter = PermutationImportance(
    model, 
    scoring='accuracy', 
    n_iter=5, 
    random_state=42
)

permuter.fit(x_val_transformed, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestClassifier(bootstrap=True,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=None,
#                                                        max_features='auto',
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=100,
#                                                        n_jobs=-1,
#                                                        oob_score=False,
#                                                        random_state=42,
#                                                        verbose=0,
#                                                        warm_start=False),
#                       n_iter=5, random_state=42, refit=True,
#                       scoring='accuracy')

# %%
feature_names = x_val.columns.tolist()
pd.Series(permuter.feature_importances_, feature_names).sort_values()
# Out:
# location_id         -0.007285
# location_name       -0.004636
# currency            -0.002318
# currency_symbol     -0.002318
# location            -0.002318
# location_state      -0.001656
# slug_length          0.000000
# name_length          0.000000
# blurb_len            0.000000
# photo                0.000000
# blurb                0.000000
# slug                 0.000000
# name                 0.000331
# is_usd               0.000662
# country              0.001987
# is_usa               0.002649
# category_color       0.003311
# launched_at          0.003642
# id                   0.005298
# category_name        0.006291
# category_slug        0.007616
# created_at           0.011589
# category             0.011589
# category_position    0.018212
# deadline             0.029470
# goal                 0.029801
# category_id          0.047351
# staff_pick           0.060927
# dtype: float64

# %%
# 2. Display permutation importances
eli5.show_weights(
    permuter, 
    top=None, # show permutation importances for all features
    feature_names=feature_names # must be a list
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0609
#
#                     &plusmn; 0.0245
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 staff_pick
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0474
#
#                     &plusmn; 0.0170
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 category_id
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0298
#
#                     &plusmn; 0.0188
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 goal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0295
#
#                     &plusmn; 0.0110
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 deadline
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0182
#
#                     &plusmn; 0.0191
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 category_position
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#                     &plusmn; 0.0086
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 category
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#                     &plusmn; 0.0081
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 created_at
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0076
#
#                     &plusmn; 0.0110
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 category_slug
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0063
#
#                     &plusmn; 0.0112
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 category_name
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0053
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 id
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0036
#
#                     &plusmn; 0.0167
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 launched_at
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0033
#
#                     &plusmn; 0.0105
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 category_color
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#                     &plusmn; 0.0061
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_usa
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 country
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0061
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_usd
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 name
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 slug
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>

# %%
print('Shape before removing features:', x_train.shape, x_test.shape)

minimum_importance = 0
mask = permuter.feature_importances_ > minimum_importance
features = x_train.columns[mask]
x_train = x_train[features]

features = x_test.columns[mask]
x_test = x_test[features]

print('Shape after removing features:', x_train.shape, x_test.shape)
# Out:
# Shape before removing features: (2416, 28) (755, 28)
# Shape after removing features: (2416, 16) (755, 16)

# %%
x_val = x_val[features]

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(x_train, y_train)
print('Validation Accuracy', pipeline.score(x_val, y_val))
# Out:
# Validation Accuracy 0.7334437086092715

# %%
from xgboost import XGBClassifier

pipeline2 = make_pipeline(
    ce.OrdinalEncoder(), 
    XGBClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

pipeline2.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['category', 'country', 'name',
#                                       'category_name', 'category_slug'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value',
#                                 mapping=[{'col': 'category',
#                                           'data_type': dtype('O'),
#                                           'mapping': {"id":278,"name":"People","slug":"photography/people","position":4,"parent_id":15,"color":58341...
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=-1, nthread=None,
#                                objective='multi:softprob', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)

# %%
from sklearn.metrics import accuracy_score
y_pred = pipeline2.predict(x_val)
print('Validation Accuracy', accuracy_score(y_val, y_pred))
# Out:
# Validation Accuracy 0.7350993377483444

# %%
# fit_transfom on train, transform on val
encoder = ce.OrdinalEncoder()
x_train_encoded = encoder.fit_transform(x_train)
x_val_encoded = encoder.transform(x_val)

model = XGBClassifier(
    n_estimators=1000,  # <= 1000 trees, depends on early stopping
    max_depth=7,        # try deeper trees because of high cardinality categoricals
    learning_rate=0.5,  # try higher learning rate
    n_jobs=-1
)

eval_set = [(x_train_encoded, y_train), 
            (x_val_encoded, y_val)]

model.fit(x_train_encoded, y_train, 
          eval_set=eval_set,
          eval_metric='merror', 
          early_stopping_rounds=50) # Stop if the score hasn't improved in 50 rounds
# Out:
# [0]	validation_0-merror:0.247517	validation_1-merror:0.299669
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 50 rounds.
# [1]	validation_0-merror:0.208195	validation_1-merror:0.279801
# [2]	validation_0-merror:0.19702	validation_1-merror:0.269868
# [3]	validation_0-merror:0.175083	validation_1-merror:0.243377
# [4]	validation_0-merror:0.159354	validation_1-merror:0.246689
# [5]	validation_0-merror:0.137831	validation_1-merror:0.259934
# [6]	validation_0-merror:0.131623	validation_1-merror:0.254967
# [7]	validation_0-merror:0.112583	validation_1-merror:0.264901
# [8]	validation_0-merror:0.105546	validation_1-merror:0.268212
# [9]	validation_0-merror:0.082368	validation_1-merror:0.266556
# [10]	validation_0-merror:0.06457	validation_1-merror:0.27649
# [11]	validation_0-merror:0.054222	validation_1-merror:0.259934
# [12]	validation_0-merror:0.050911	validation_1-merror:0.264901
# [13]	validation_0-merror:0.047185	validation_1-merror:0.264901
# [14]	validation_0-merror:0.038079	validation_1-merror:0.264901
# [15]	validation_0-merror:0.031043	validation_1-merror:0.256623
# [16]	validation_0-merror:0.029801	validation_1-merror:0.268212
# [17]	validation_0-merror:0.024007	validation_1-merror:0.259934
# [18]	validation_0-merror:0.019454	validation_1-merror:0.263245
# [19]	validation_0-merror:0.016142	validation_1-merror:0.258278
# [20]	validation_0-merror:0.012831	validation_1-merror:0.256623
# [21]	validation_0-merror:0.012003	validation_1-merror:0.258278
# [22]	validation_0-merror:0.011589	validation_1-merror:0.268212
# [23]	validation_0-merror:0.00745	validation_1-merror:0.266556
# [24]	validation_0-merror:0.005381	validation_1-merror:0.263245
# [25]	validation_0-merror:0.005381	validation_1-merror:0.263245
# [26]	validation_0-merror:0.004967	validation_1-merror:0.266556
# [27]	validation_0-merror:0.003311	validation_1-merror:0.268212
# [28]	validation_0-merror:0.003311	validation_1-merror:0.269868
# [29]	validation_0-merror:0.001656	validation_1-merror:0.269868
# [30]	validation_0-merror:0.001656	validation_1-merror:0.27649
# [31]	validation_0-merror:0.000828	validation_1-merror:0.278146
# [32]	validation_0-merror:0.000828	validation_1-merror:0.278146
# [33]	validation_0-merror:0.000828	validation_1-merror:0.278146
# [34]	validation_0-merror:0.000828	validation_1-merror:0.281457
# [35]	validation_0-merror:0.000414	validation_1-merror:0.279801
# [36]	validation_0-merror:0.000414	validation_1-merror:0.278146
# [37]	validation_0-merror:0.000414	validation_1-merror:0.283113
# [38]	validation_0-merror:0	validation_1-merror:0.278146
# [39]	validation_0-merror:0	validation_1-merror:0.281457
# [40]	validation_0-merror:0	validation_1-merror:0.283113
# [41]	validation_0-merror:0	validation_1-merror:0.27649
# [42]	validation_0-merror:0	validation_1-merror:0.278146
# [43]	validation_0-merror:0	validation_1-merror:0.273179
# [44]	validation_0-merror:0	validation_1-merror:0.273179
# [45]	validation_0-merror:0	validation_1-merror:0.279801
# [46]	validation_0-merror:0	validation_1-merror:0.274834
# [47]	validation_0-merror:0	validation_1-merror:0.273179
# [48]	validation_0-merror:0	validation_1-merror:0.27649
# [49]	validation_0-merror:0	validation_1-merror:0.279801
# [50]	validation_0-merror:0	validation_1-merror:0.281457
# [51]	validation_0-merror:0	validation_1-merror:0.281457
# [52]	validation_0-merror:0	validation_1-merror:0.281457
# [53]	validation_0-merror:0	validation_1-merror:0.279801
# Stopping. Best iteration:
# [3]	validation_0-merror:0.175083	validation_1-merror:0.243377
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.5, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
results = model.evals_result()
train_error = results['validation_0']['merror']
val_error = results['validation_1']['merror']
epoch = range(1, len(train_error)+1)
plt.plot(epoch, train_error, label='Train')
plt.plot(epoch, val_error, label='Validation')
plt.ylabel('Classification Error')
plt.xlabel('Model Complexity (n_estimators)')
#plt.ylim((0.18, 0.22)) # Zoom in
plt.legend();

# %%
'''
So with about 6000(2files) rows the accuracy was about 62% to about 67%
with original train test val

with 6000(2 files) rows with train test val v2 we had as high as 72%
when 

50files accuracies at 79% on 74%when using xgboost

100files accuracies where at 87% and 74%when using xgboost

'''
# Out:
# '\nSo with about 6000(2files) rows the accuracy was about 62% to about 67%\nwith original train test val\n\nwith 6000(2 files) rows with train test val v2 we had as high as 72%\nwhen \n\n50files accuracies at 79% on 74%when using xgboost\n\n100files accuracies where at 87% and 74%when using xgboost\n\n'

# %%
'''
2files using the newly created location features we jumped to 73%-74%

50files had about 80% using xgboost had 74%. I think somthing is wrong with xgboost

100files had about 89% accuracy

300files 97.8% accuracy. data is powerful
'''
# Out:
# '\n2files using the newly created location features we jumped to 73%-74%\n\n50files had about 80% using xgboost had 74%. I think somthing is wrong with xgboost\n\n100files had about 89% accuracy\n\n300files 97.8% accuracy. data is powerful\n'

# %%
df[features].isnull().sum()
# Out:
# category             0
# country              0
# created_at           0
# deadline             0
# goal                 0
# id                   0
# launched_at          0
# name                 0
# staff_pick           0
# category_id          0
# category_name        0
# category_slug        0
# category_position    0
# category_color       0
# is_usa               0
# is_usd               0
# dtype: int64

# %%
#creating a partial dependance plot for df

import category_encoders as ce
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier



X = df[features]
y = df[target]

encoder = ce.OrdinalEncoder()
X_encoded = encoder.fit_transform(X)

model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(X_encoded, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# Use Pdpbox
# %matplotlib inline
import matplotlib.pyplot as plt
from pdpbox import pdp
feature = 'deadline'
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_encoded, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature);

# %%
x_train.shape
# Out:
# (2416, 16)

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier

processor = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_processed = processor.fit_transform(x_train)
X_val_processed = processor.transform(x_val)

eval_set = [(X_train_processed, y_train), 
            (X_val_processed, y_val)]

model = XGBClassifier(n_estimators=1000, n_jobs=-1)
model.fit(X_train_processed, y_train, eval_set=eval_set, eval_metric='auc', 
          early_stopping_rounds=10)

# %%
test_test = df[features]
row = x_test.iloc[[500]]
print(row)
# Out:
#                                               category country  created_at  \
# 623  {"id":26,"name":"Crafts","slug":"crafts","posi...      US  1397092593
#
#        deadline   goal         id  launched_at  \
# 623  1416545940  11000  206508834   1413386998
#
#                                      name  staff_pick  category_id  \
# 623  Fruitimals Plush Toys - FINAL HOURS!        True           26
#
#     category_name category_slug  category_position  category_color  is_usa  \
# 623        Crafts        crafts                  3        16744876    True
#
#      is_usd
# 623    True

# %%
x_test.shape
# Out:
# (755, 16)

# %%
x_train.shape
# Out:
# (2416, 16)

# %%
# STUDY/PRACTICE THIS CELL FOR THE SPRINT CHALLENGE
import shap

explainer = shap.TreeExplainer(model)
row_processed = processor.transform(row)
shap_values = explainer.shap_values(row_processed)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value, 
    shap_values=shap_values, 
    features=row, 
    link='logit' # For classification, this shows predicted probabilities
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-223-40cc7e873b68> in <module>
#      11     shap_values=shap_values,
#      12     features=row,
# ---> 13     link='logit' # For classification, this shows predicted probabilities
#      14 )
#
# ~\Anaconda3\lib\site-packages\shap\plots\force.py in force_plot(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation)
#      76
#      77
# ---> 78     assert not type(shap_values) == list, "The shap_values arg looks looks multi output, try shap_values[i]."
#      79
#      80     link = convert_to_link(link)
#
# AssertionError: The shap_values arg looks looks multi output, try shap_values[i].
